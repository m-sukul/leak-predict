# 10    55.50    55.50    55.50    55.50          NaN
# 11    54.46    54.46    54.46    54.46          NaN
# 12    50.30    50.30    50.30    50.30          NaN
# 13    52.03    52.03    52.03    52.03          NaN
# 14    54.12    54.12    54.12    54.12          NaN
# 15    53.32    53.32    53.32    53.32          NaN
# 16    52.23    52.23    52.23    52.23          NaN
# 17    55.19    55.19    55.19    55.19          NaN
# 18    55.06    55.06    55.06    55.06          NaN
# 19    52.63    52.63    52.63    52.63          NaN
# 20    50.80    50.80    50.80    50.80          NaN
# 21    52.75    52.75    52.75    52.75          NaN
# 22    51.35    51.35    51.35    51.35          NaN
# 23    43.65    43.65    43.65    43.65          NaN
# 24    51.91    51.91    51.91    51.91          NaN
# 25    55.18    55.18    55.18    55.18          NaN
# 26    55.04    55.04    55.04    55.04          NaN
# 27    45.55    45.55    45.55    45.55          NaN
# 28    49.19    49.19    49.19    49.19          NaN
# 29    46.44    46.44    46.44    46.44          NaN
# 30    56.34    56.34    56.34    56.34          NaN
# 31    55.41    55.41    55.41    55.41          NaN
# 32    55.29    55.29    55.29    55.29          NaN
# 33    55.60    55.60    55.60    55.60          NaN
# 34    49.98    49.98    49.98    49.98          NaN
# 35    51.36    51.36    51.36    51.36          NaN
# 36  3710.94  3710.94  3710.94  3710.94          NaN

# %%
nodes=36

# %%
diffs=pd.DataFrame()
diffs['nodes']=range(1,nodes+1)
for i in range(1,nodes+1):
    a=pd.read_csv(path+"n"+str(i)+"_1.csv")
    diff=np.array((orig.iloc[:nodes,1])-a.iloc[:nodes,1])
    diffs[str(i)]=diff
diffs=diffs.set_index('nodes')

# %%
diffs
# Out:
#              1        2        3        4         5         6         7  \
# nodes
# 1      0.00262  0.00260  0.00260  0.00261   0.00257   0.00258   0.00258
# 2      0.00010  5.71253  0.70689  0.13409   0.08595   0.07420   0.06441
# 3      0.00436  0.90589  6.38788  0.42594   0.24653   0.15774   0.12497
# 4     -0.00033  0.19126  0.44266  3.52983   1.38831   0.40004   0.25362
# 5      0.00390  0.14434  0.30715  2.04856  20.77589   3.77921   2.02748
# 6      0.00305  0.09986  0.18451  0.54454   2.31586  12.89270   4.46466
# 7      0.00487  0.08887  0.14208  0.26044   0.73792   3.35103  16.61003
# 8      0.00120  0.06981  0.08254  0.09734   0.11307   0.26942   0.60677
# 9      0.00412  0.01664  0.01822  0.02021   0.01965   0.03773   0.07445
# 10    -0.00137  0.07030  0.07367  0.07714   0.05410   0.05876   0.05442
# 11     0.00292  0.08885  0.15700  0.17340   0.12189   0.12715   0.10952
# 12    -0.00064  0.11915  0.24511  1.12496   0.64720   0.25553   0.17677
# 13     0.00350  0.12148  0.24465  1.12646   2.23539   0.74411   0.44102
# 14     0.00054  0.08737  0.15783  0.26262   0.44429   1.24301   0.70226
# 15    -0.00002  0.08385  0.14993  0.18361   0.18675   0.40358   0.34847
# 16    -0.00171  0.07370  0.08351  0.09178   0.07926   0.13389   0.20945
# 17     0.00357  0.27352  0.05266  0.01142   0.01015   0.01141   0.00899
# 18    -0.00206  0.39974  0.11501  0.08032   0.05523   0.05880   0.05402
# 19     0.00523  0.10717  0.20258  0.61821   0.37206   0.19407   0.14663
# 35     0.01675  0.17477  0.15299  5.72692  2.40480
# 36     0.00780  0.08238  0.06391  2.07804  3.28686
#
# [36 rows x 36 columns]

# %%
sums=pd.DataFrame()

# %%
sums=pd.DataFrame()
sums['sum']=diffs.sum(axis=1)

# %%
sums
# Out:
#             sum
# nodes
# 1       0.06255
# 2       9.36311
# 3      11.37665
# 4      11.63992
# 5      40.99810
# 6      33.38082
# 7      36.34469
# 8      23.22655
# 9      25.18740
# 10      1.97275
# 11      3.51255
# 12      7.82968
# 13     18.74949
# 14     14.62422
# 15      6.92118
# 16      7.30507
# 17      6.04823
# 18      2.85647
# 19      5.94646
# 20     12.36908
# 21     17.25451
# 22      9.54091
# 23     13.38187
# 24     27.34633
# 25     11.07084
# 26      4.86944
# 27      4.26721
# 28     48.33547
# 29     22.81855
# 30     40.69446
# 31      0.65825
# 32      2.68972
# 33      2.70164
# 34      1.72488
# 35     15.39437
# 36     11.48894

# %%
type(sums)
# Out:
# pandas.core.frame.DataFrame

# %%
sums.sort_values('sum',inplace=True)

# %%
sums
# Out:
#             sum
# nodes
# 1       0.06255
# 31      0.65825
# 34      1.72488
# 10      1.97275
# 32      2.68972
# 33      2.70164
# 18      2.85647
# 11      3.51255
# 27      4.26721
# 26      4.86944
# 19      5.94646
# 17      6.04823
# 15      6.92118
# 16      7.30507
# 12      7.82968
# 2       9.36311
# 22      9.54091
# 25     11.07084
# 3      11.37665
# 36     11.48894
# 4      11.63992
# 20     12.36908
# 23     13.38187
# 14     14.62422
# 35     15.39437
# 21     17.25451
# 13     18.74949
# 29     22.81855
# 8      23.22655
# 9      25.18740
# 24     27.34633
# 6      33.38082
# 7      36.34469
# 30     40.69446
# 5      40.99810
# 28     48.33547

# %%
s=pd.DataFrame()
s['s']=sums.iloc[:,0]

# %%
s['a']=range(1,nodes+1)
s.set_index('a',inplace=True)

# %%
s.plot()

# %%
sums.index
# Out:
# Int64Index([ 1, 31, 34, 10, 32, 33, 18, 11, 27, 26, 19, 17, 15, 16, 12,  2, 22,
#             25,  3, 36,  4, 20, 23, 14, 35, 21, 13, 29,  8,  9, 24,  6,  7, 30,
#              5, 28],
#            dtype='int64', name='nodes')

# %%
sensors=np.array(sums.index)

# %%
sensors
# Out:
# array([ 1, 31, 34, 10, 32, 33, 18, 11, 27, 26, 19, 17, 15, 16, 12,  2, 22,
#        25,  3, 36,  4, 20, 23, 14, 35, 21, 13, 29,  8,  9, 24,  6,  7, 30,
#         5, 28], dtype=int64)

# %%
limit=36
n=len(sensors)
i=n//2 -1
left=i-limit//2
right=i+limit//2+1
sensors[left:right]
# Out:
# array([28], dtype=int64)

# %%
def extractp():
    path="G:\\research\\auto\\fos_read\\"
    orig=pd.read_csv(path+'original.csv')
    diffs=pd.DataFrame()
    diffs['nodes']=range(1,nodes+1)
    for i in range(1,nodes+1):
        a=pd.read_csv(path+"n"+str(i)+"_1.csv")
        diff=np.array((orig.iloc[:nodes,1])-a.iloc[:nodes,1])
        diffs[str(i)]=diff
    diffs=diffs.set_index('nodes')
    
    sums=pd.DataFrame()
    sums['sum']=diffs.sum(axis=1)
    sums.sort_values('sum',inplace=True)
    sensors=np.array(sums.index)
    return sensors

# %%
nodes=36
def get_sensors(limit=nodes):
    sensors=extractp()
    n=len(sensors)
    i=n//2 -1
    left=i-limit//2
    right=i+limit//2+1
    sensors=sensors[left:right]
    sensors=sensors-1
    return sensors.tolist()

# %%
print(get_sensors(6))
# Out:
# [11, 1, 21, 24, 2, 35, 3]

# %%
s=np.array(get_sensors(6))
print(s-1)
# Out:
# [11  1 21 24  2 35  3]

# %% [markdown]
# ## TRAINING

# %%
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
import numpy
from keras.models import Sequential,model_from_json
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from sklearn.metrics import accuracy_score

# %%
d=pd.read_csv(path+"fos_final.csv",header=None)
d=d.T
print(d.shape)
# Out:
# (108, 37)

# %%
d
# Out:
#            0         1         2         3         4         5         6   \
# 0    55.84738  52.04990  52.67564  53.36033  46.05610  42.60695  42.70513
# 1    55.84730  52.04982  52.67557  53.36026  46.05603  42.60688  42.70504
# 2    55.84732  52.04985  52.67559  53.36029  46.05605  42.60691  42.70507
# 3    55.84740  46.33747  51.77411  53.16874  45.91566  42.51014  42.62113
# 4    55.84733  43.05161  51.49061  53.12025  45.87429  42.47485  42.58890
# ..        ...       ...       ...       ...       ...       ...       ...
# 103  55.84748  52.04662  52.67189  53.35638  46.05085  42.59924  42.68955
# 104  55.84749  52.04686  52.67215  53.35665  46.05120  42.59975  42.69062
# 105  55.84739  52.04359  52.66835  53.35250  46.04416  42.58705  42.65519
# 106  55.84748  52.04787  52.67320  53.35767  46.05195  42.59996  42.68854
# 107  55.84748  52.04787  52.67320  53.35767  46.05195  42.59996  42.68854
#
#            7         8         9   ...        27        28        29  \
# 0    46.02880  47.68588  55.75137  ...  45.54602  49.19342  46.43758
# 1    46.02871  47.68579  55.75129  ...  45.54595  49.19335  46.43750
# 2    46.02874  47.68583  55.75131  ...  45.54597  49.19337  46.43752
# 3    45.96019  47.67336  55.67970  ...  45.51109  49.16566  46.42041
# 4    45.93436  47.66858  55.65004  ...  45.49791  49.15534  46.41393
# ..        ...       ...       ...  ...       ...       ...       ...
# 103  45.95012  47.01224  55.74791  ...  45.15261  48.89413  45.43560
# 104  45.95554  47.05864  55.74815  ...  45.18026  48.91508  45.50721
# 105  45.74368  44.89447  55.74483  ...  43.94270  48.51642  44.52594
# 106  45.93341  46.75725  55.74925  ...  45.04937  48.97475  45.82767
# 107  45.93341  46.75725  55.74925  ...  45.04937  48.97475  45.82767
#
#            30        31        32        33        34        35    36
# 0    56.33562  55.41059  55.28765  55.60056  49.97756  51.36154   1.0
# 1    56.33554  55.41051  55.28757  55.60048  49.97749  51.36147   1.0
# 2    56.33556  55.41054  55.28759  55.60051  49.97751  51.36148   1.0
# 3    56.31995  55.33874  55.26897  55.58394  49.96770  51.35578   2.0
# 4    56.31345  55.30918  55.26222  55.57739  49.96385  51.35353   2.0
# ..        ...       ...       ...       ...       ...       ...   ...
# 103  56.33302  55.40624  55.23707  55.55674  48.15789  50.65978  35.0
# 104  56.33320  55.40655  55.24052  55.55973  48.28634  50.70774  35.0
# 105  56.33150  55.40129  55.20821  55.53824  47.57520  48.07314  36.0
# 106  56.33432  55.40765  55.26143  55.57994  49.20802  50.26259  36.0
# 107  56.33432  55.40765  55.26143  55.57994  49.20802  50.26259  36.0
#
# [108 rows x 37 columns]

# %%
df = pd.DataFrame(d)

# %%
from sklearn.linear_model import LogisticRegressionCV
score=[]
for i in range(1,nodes-28):
    fd=df[get_sensors(i)]
    X=fd
    Y1 = d.iloc[:,36]
    Y= numpy.array(Y1)
    Y=Y1.values
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.4,random_state=1,stratify=Y)
    clf = LogisticRegressionCV(cv=2,max_iter=20000,random_state=1, solver='lbfgs',multi_class='multinomial')
    clf.fit(X,Y)
    print(clf.score(X_test,y_test))
    score.append(clf.score(X_test,y_test))
plt.plot(score)
plt.show()
# Out:
# 0.1590909090909091
# 0.5
# 0.5
# 0.8863636363636364
# 0.8863636363636364
# c:\users\sreej\.conda\envs\research\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 0.9772727272727273
# 0.9772727272727273
# c:\users\sreej\.conda\envs\research\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
fd=df[[1,21,24,2,34,3]]

# %%
X=fd

# %%
X
# Out:
#            1         21        24        2         34        3
# 0    52.04990  52.74591  51.90799  52.67564  49.97756  53.36033
# 1    52.04982  52.74584  51.90791  52.67557  49.97749  53.36026
# 2    52.04985  52.74586  51.90794  52.67559  49.97751  53.36029
# 3    46.33747  52.66181  51.83284  51.77411  49.96770  53.16874
# 4    43.05161  52.62787  51.80459  51.49061  49.96385  53.12025
# ..        ...       ...       ...       ...       ...       ...
# 103  52.04662  52.73964  51.89166  52.67189  48.15789  53.35638
# 104  52.04686  52.74004  51.89285  52.67215  48.28634  53.35665
# 105  52.04359  52.73214  51.85497  52.66835  47.57520  53.35250
# 106  52.04787  52.74076  51.89114  52.67320  49.20802  53.35767
# 107  52.04787  52.74076  51.89114  52.67320  49.20802  53.35767
#
# [108 rows x 6 columns]

# %%
Y
# Out:
# array([ 1.,  1.,  1.,  2.,  2.,  2.,  3.,  3.,  3.,  4.,  4.,  4.,  5.,
#         5.,  5.,  6.,  6.,  6.,  7.,  7.,  7.,  8.,  8.,  8.,  9.,  9.,
#         9., 10., 10., 10., 11., 11., 11., 12., 12., 12., 13., 13., 13.,
#        14., 14., 14., 15., 15., 15., 16., 16., 16., 17., 17., 17., 18.,
#        18., 18., 19., 19., 19., 20., 20., 20., 21., 21., 21., 22., 22.,
#        22., 23., 23., 23., 24., 24., 24., 25., 25., 25., 26., 26., 26.,
#        27., 27., 27., 28., 28., 28., 29., 29., 29., 30., 30., 30., 31.,
#        31., 31., 32., 32., 32., 33., 33., 33., 34., 34., 34., 35., 35.,
#        35., 36., 36., 36.])

# %%
Y1 = d.iloc[:,36]
Y= numpy.array(Y1)
Y=Y1.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.4,random_state=1,stratify=Y)
print(y_train)
# Out:
# [ 9.  3. 35. 11. 22. 32. 33. 31. 25. 28. 17.  4. 25. 18. 10. 15. 35.  4.
#  19.  1. 23. 20. 29. 21. 36. 22. 13. 28. 24.  6. 30. 30.  2. 32. 27. 31.
#  19. 26. 16. 29. 11. 15.  7. 33. 21. 12.  3. 27. 34. 24. 23. 20. 14. 26.
#  36. 34.  5.  8.  5.  7. 14. 18.  8.  2.]

# %%
from sklearn.linear_model import LogisticRegressionCV
clf = LogisticRegressionCV(cv=2,max_iter=20000,random_state=1, solver='lbfgs',multi_class='multinomial')
clf.fit(X,Y)
clf.score(X_test,y_test)
# Out:
# c:\users\sreej\.conda\envs\research\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# c:\users\sreej\.conda\envs\research\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# 1.0

# %%
X_train.shape
# Out:
# (64, 6)

# %%
y_train.shape
# Out:
# (64,)
